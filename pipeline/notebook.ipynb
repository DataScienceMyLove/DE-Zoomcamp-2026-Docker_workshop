# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
pd.__file__
# Out:
# '/workspaces/DE-Zoomcamp-2026-Docker_workshop/pipeline/.venv/lib/python3.13/site-packages/pandas/__init__.py'
